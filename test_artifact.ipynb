# %%
import os
import mlflow

# %%
mlflow.set_tracking_uri("http://0.0.0.0:5000")

# %%
experiment_id = mlflow.get_experiment_by_name("Default").experiment_id

# %%
with mlflow.start_run(run_name="Default", experiment_id=experiment_id) as run:
    run_id = run.info.run_id

    mlflow.log_metric("test_metric_sqlite", 0)
    mlflow.log_artifact("test_artifact.txt", "test_artifact_sqlite")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 5
#       2 run_id = run.info.run_id
#       4 mlflow.log_metric("test_metric_sqlite", 0)
# ----> 5 mlflow.log_artifact("test_artifact.txt", "test_artifact_sqlite")
#
# File ~/mle_projects/mlflow/.venv/lib/python3.10/site-packages/mlflow/tracking/fluent.py:874, in log_artifact(local_path, artifact_path)
#     851 """
#     852 Log a local file or directory as an artifact of the currently active run. If no run is
#     853 active, this method will create a new active run.
#    (...)
#     871         mlflow.log_artifact("features.txt")
#     872 """
#     873 run_id = _get_or_start_run().info.run_id
# --> 874 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File ~/mle_projects/mlflow/.venv/lib/python3.10/site-packages/mlflow/tracking/client.py:1092, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    1057 def log_artifact(self, run_id, local_path, artifact_path=None) -> None:
#    1058     """
#    1059     Write a local file or directory to the remote ``artifact_uri``.
#    1060
#    (...)
#    1090         is_dir: False
#    1091     """
# -> 1092     self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File ~/mle_projects/mlflow/.venv/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:454, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     452     artifact_repo.log_artifacts(local_path, path_name)
#     453 else:
# --> 454     artifact_repo.log_artifact(local_path, artifact_path)
#
# File ~/mle_projects/mlflow/.venv/lib/python3.10/site-packages/mlflow/store/artifact/local_artifact_repo.py:38, in LocalArtifactRepository.log_artifact(self, local_file, artifact_path)
#      36     mkdir(artifact_dir)
#      37 try:
# ---> 38     shutil.copyfile(local_file, os.path.join(artifact_dir, os.path.basename(local_file)))
#      39 except shutil.SameFileError:
#      40     pass
#
# File /usr/lib/python3.10/shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
#     256             with open(dst, 'wb') as fdst:
#     257                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_artifact.txt'

# %%
print(f"Run id: {run_id}")
# Out:
# Run id: 7b384b446e2c4e859c43ab741adeee9a

# %%
# !ls mlflow_experiments_store/0/{run_id}/metrics
# Out:
# test_metric

# %%
# !cat mlflow_experiments_store/0/{run_id}/artifacts/test_artifact/test_artifact.txt
# Out:
# cat: mlflow_experiments_store/0/6b2210e71f864a5dbc8b4eaa9f15fce8/artifacts/test_artifact/test_artifact.txt: No such file or directory

# %%
assert os.path.exists("mlflow_experiments_store_sqlite")
assert os.path.exists("mydb.sqlite")
